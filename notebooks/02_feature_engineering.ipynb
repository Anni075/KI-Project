# %% [markdown]
# # Feature Engineering

# %%
import sys
sys.path.insert(0, '..')

from src.data.preprocessing import load_pv_data, compute_pv_surplus
from src.features.feature_engineering import add_time_features, add_lag_features

df = load_pv_data()
df = compute_pv_surplus(df)
df = add_time_features(df)
df = add_lag_features(df)
df.head()
