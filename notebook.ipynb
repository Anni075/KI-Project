# %% [markdown]
# Explorative Datenanalyse

# %%
print("Hello World")
# Out:
# Hello World

# %%
# ===============================================
# 1. Setup & Datenimport
# ===============================================
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# CSV-Datei einlesen (Pfad anpassen)
df = pd.read_csv("data/pv_data.csv", sep=";", parse_dates=["timestamp"])

# Kurzer Überblick
print("Datenvorschau:")
display(df.head())

print("\nAllgemeine Infos:")
df.info()

# ===============================================
# 2. Grundlegende Datenprüfung
# ===============================================
print("\nFehlende Werte pro Spalte:")
print(df.isna().sum())

print("\nStatistische Grundwerte:")
display(df.describe())

# ===============================================
# 3. Zeitraum & Zeitauflösung
# ===============================================
start = df["timestamp"].min()
ende = df["timestamp"].max()
dauer = ende - start

print(f"\nZeitraum: {start} bis {ende}")
print(f"Dauer: {dauer}")

# ===============================================
# 4. Kategorien für Analyse definieren
# ===============================================
# Solarproduktion: alle relevanten Spalten
solar_cols = [
    "Solarproduktion Tracker 1",
    "Solarproduktion Tracker 2",
    "Solarproduktion Tracker 3",
    "Solarproduktion"
]

# Wallbox-Gesamtladeleistung & Solarladeleistung
wallbox_cols = [
    "Wallbox (ID 0) Gesamtladeleistung",
    "Wallbox Gesamtladeleistung",
    "Wallbox (ID 0) Solarladeleistung"
]

# ===============================================
# 5. Kennzahlen (Mittel, Min, Max)
# ===============================================
def summary_stats(columns):
    return df[columns].agg(["mean", "min", "max"]).T.rename(
        columns={"mean": "Durchschnitt", "min": "Minimum", "max": "Maximum"}
    )

print("\n--- Solarproduktion ---")
display(summary_stats(solar_cols))

print("\n--- Wallbox-Leistungen ---")
display(summary_stats(wallbox_cols))

# ===============================================
# 6. Visualisierung
# ===============================================
sns.set_style("whitegrid")
plt.figure(figsize=(12,6))
plt.plot(df["timestamp"], df["Solarproduktion"], label="Solarproduktion (gesamt)", color="orange")
plt.title("Solarproduktion über Zeit")
plt.xlabel("Zeit")
plt.ylabel("Leistung [kW]")
plt.legend()
plt.show()

plt.figure(figsize=(12,6))
plt.plot(df["timestamp"], df["Wallbox Gesamtladeleistung"], label="Wallbox Gesamt", color="blue")
plt.plot(df["timestamp"], df["Wallbox (ID 0) Solarladeleistung"], label="Wallbox Solarladung", color="green")
plt.title("Wallbox-Leistung über Zeit")
plt.xlabel("Zeit")
plt.ylabel("Leistung [kW]")
plt.legend()
plt.show()

# ===============================================
# 7. Vergleich: Hausverbrauch (ohne Wallbox) vs. Solarproduktion
# ===============================================

# Neue Spalte: Hausverbrauch ohne Wallbox
df["Hausverbrauch_ohne_Wallbox"] = df["Hausverbrauch"] - df["Wallbox Gesamtladeleistung"]

# Summenvergleich über gesamten Zeitraum
gesamt_solar = df["Solarproduktion"].sum()
gesamt_haus = df["Hausverbrauch_ohne_Wallbox"].sum()

print("\n--- Gesamtvergleich ---")
print(f"Gesamte Solarproduktion: {gesamt_solar:.2f} kWh")
print(f"Gesamter Hausverbrauch ohne Wallbox: {gesamt_haus:.2f} kWh")

deckung = (gesamt_solar / gesamt_haus) * 100 if gesamt_haus > 0 else 0
print(f"Solarproduktion deckt {deckung:.1f}% des Haushaltsverbrauchs (ohne Wallbox)")

# ===============================================
# 8. Zeitliche Visualisierung
# ===============================================
plt.figure(figsize=(12,6))
plt.plot(df["timestamp"], df["Solarproduktion"], label="Solarproduktion", color="orange")
plt.plot(df["timestamp"], df["Hausverbrauch"], label="Hausverbrauch", color="red")
plt.title("Vergleich: Solarproduktion vs. Hausverbrauch (ohne Wallbox)")
plt.xlabel("Zeit")
plt.ylabel("Leistung [kW]")
plt.legend()
plt.show()

# ===============================================
# 12. Tagesprofile (optional)
# ===============================================
df["hour"] = df["timestamp"].dt.hour
solar_by_hour = df.groupby("hour")["Solarproduktion"].mean()
hausbedarf_by_hour = df.groupby("hour")["Hausverbrauch"].mean()

plt.figure(figsize=(10,5))
plt.plot(solar_by_hour, label="Ø Solarproduktion", color="orange")
plt.plot(hausbedarf_by_hour, label="Ø Hausverbrauch Gesamt", color="blue")
plt.title("Durchschnittlicher Tagesverlauf")
plt.xlabel("Stunde des Tages")
plt.ylabel("Leistung [kW]")
plt.legend()
plt.show()

# ===============================================
# 13. Erste Interpretation
# ===============================================
print("\nErste Erkenntnisse:")
print("- Die höchste Solarproduktion liegt typischerweise zwischen 10 und 15 Uhr.")
print("- Optimaler Ladezeitpunkt für E-Fahrzeug ist bei hoher Solarproduktion und geringer Netzbezugslast.")
print("- Nächster Schritt: Prädiktives Modell (z.B. Regression oder Zeitreihenanalyse) für Ladezeit-Vorhersage.")
# Out:
# Datenvorschau:
#             timestamp  Ladezustand  Batterie (Laden)  Batterie (Entladen)  \
# 0 2022-02-07 14:00:00           23                 0                    0
# 1 2022-02-07 14:15:00           23                 0                    0
# 2 2022-02-07 14:30:00           23                 0                    0
# 3 2022-02-07 14:45:00           23                 0                    0
# 4 2022-02-07 15:00:00           23                 0                    0
#
#    Netzeinspeisung  Netzbezug  Solarproduktion Tracker 1  \
# 0                5         73                         82
# 1                2          2                         81
# 2                2          2                         80
# 3                3          3                        109
# 4                5         12                         72
#
#    Solarproduktion Tracker 2  Solarproduktion Tracker 3  Solarproduktion  \
# 0                        110                          0              192
# 1                        125                          0              206
# 2                        126                          0              206
# 3                        106                          0              215
# 4                        146                          0              218
#
#    Hausverbrauch  Wallbox (ID 0) Gesamtladeleistung  Wallbox (ID 0) Netzbezug  \
# 0            257                                NaN                       NaN
# 1            201                                NaN                       NaN
# 2            204                                NaN                       NaN
# 3            211                                NaN                       NaN
# 4            220                                NaN                       NaN
#
#    Wallbox (ID 0) Solarladeleistung  Wallbox Gesamtladeleistung  Σ Verbrauch
# 0                               NaN                         NaN          257
# 1                               NaN                         NaN          201
# 2                               NaN                         NaN          204
# 3                               NaN                         NaN          211
# 4                               NaN                         NaN          220
# Allgemeine Infos:
# <class 'pandas.DataFrame'>
# RangeIndex: 113896 entries, 0 to 113895
# Data columns (total 16 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   timestamp                          113896 non-null  datetime64[us]
#  1   Ladezustand                        113896 non-null  int64
#  2   Batterie (Laden)                   113896 non-null  int64
#  3   Batterie (Entladen)                113896 non-null  int64
#  4   Netzeinspeisung                    113896 non-null  int64
#  5   Netzbezug                          113896 non-null  int64
#  6   Solarproduktion Tracker 1          113896 non-null  int64
#  7   Solarproduktion Tracker 2          113896 non-null  int64
#  8   Solarproduktion Tracker 3          113896 non-null  int64
#  9   Solarproduktion                    113896 non-null  int64
#  10  Hausverbrauch                      113896 non-null  int64
#  11  Wallbox (ID 0) Gesamtladeleistung  92588 non-null   float64
#  12  Wallbox (ID 0) Netzbezug           92588 non-null   float64
#  13  Wallbox (ID 0) Solarladeleistung   92588 non-null   float64
#  14  Wallbox Gesamtladeleistung         92588 non-null   float64
#  15  Σ Verbrauch                        113896 non-null  int64
# dtypes: datetime64[us](1), float64(4), int64(11)
# memory usage: 13.9 MB
#
# Fehlende Werte pro Spalte:
# timestamp                                0
# Ladezustand                              0
# Batterie (Laden)                         0
# Batterie (Entladen)                      0
# Netzeinspeisung                          0
# Netzbezug                                0
# Solarproduktion Tracker 1                0
# Solarproduktion Tracker 2                0
# Solarproduktion Tracker 3                0
# Solarproduktion                          0
# Hausverbrauch                            0
# Wallbox (ID 0) Gesamtladeleistung    21308
# Wallbox (ID 0) Netzbezug             21308
# Wallbox (ID 0) Solarladeleistung     21308
# Wallbox Gesamtladeleistung           21308
# Σ Verbrauch                              0
# dtype: int64
#
# Statistische Grundwerte:
#                         timestamp    Ladezustand  Batterie (Laden)  \
# count                      113896  113896.000000     113896.000000
# mean   2023-10-13 14:52:59.332022      56.367985         85.004662
# min           2022-02-07 14:00:00       0.000000          0.000000
# 25%           2022-12-11 04:26:15      20.000000          0.000000
# 50%           2023-10-13 18:52:30      62.000000          0.000000
# 75%           2024-08-15 09:18:45      91.000000          0.000000
# max           2025-06-16 23:45:00     100.000000       2195.000000
# std                           NaN      35.676437        224.136751
#
#        Batterie (Entladen)  Netzeinspeisung      Netzbezug  \
# count        113896.000000    113896.000000  113896.000000
# mean             83.197399       159.446091      38.802829
# min               0.000000         0.000000       0.000000
# 25%               1.000000         1.000000       1.000000
# 50%              12.000000         1.000000       1.000000
# 75%             117.000000         3.000000       3.000000
# max            2400.000000      2180.000000    3863.000000
# std             148.560688       389.271960     169.318142
#
#        Solarproduktion Tracker 1  Solarproduktion Tracker 2  \
# count              113896.000000              113896.000000
# mean                  113.128389                 214.986268
# min                     0.000000                   0.000000
# 25%                     0.000000                   0.000000
# 50%                     1.000000                   0.000000
# 75%                   149.000000                 245.000000
# max                  1125.000000                1721.000000
# std                   188.830633                 375.524054
#
#        Solarproduktion Tracker 3  Solarproduktion  Hausverbrauch  \
# count                   113896.0    113896.000000  113896.000000
# mean                         0.0       328.114657     158.253082
# min                          0.0         0.000000       0.000000
# 25%                          0.0         0.000000      81.000000
# 50%                          0.0         2.000000     132.000000
# 75%                          0.0       522.000000     194.000000
# max                          0.0      2361.000000    2520.000000
# std                          0.0       506.766364     113.527484
#
#        Wallbox (ID 0) Gesamtladeleistung  Wallbox (ID 0) Netzbezug  \
# count                       92588.000000              92588.000000
# mean                           34.312384                 11.865739
# min                             0.000000                 -1.000000
# 25%                             0.000000                  0.000000
# 50%                             0.000000                  0.000000
# 75%                             0.000000                  0.000000
# max                          2775.000000               2698.000000
# std                           268.126110                159.340922
#
#        Wallbox (ID 0) Solarladeleistung  Wallbox Gesamtladeleistung  \
# count                      92588.000000                92588.000000
# mean                          22.446645                   34.312384
# min                            0.000000                    0.000000
# 25%                            0.000000                    0.000000
# 50%                            0.000000                    0.000000
# 75%                            0.000000                    0.000000
# max                         2758.000000                 2775.000000
# std                          201.275927                  268.126110
#
#          Σ Verbrauch
# count  113896.000000
# mean      186.146204
# min         0.000000
# 25%        81.000000
# 50%       133.000000
# 75%       197.000000
# max      3863.000000
# std       272.762503
# Zeitraum: 2022-02-07 14:00:00 bis 2025-06-16 23:45:00
# Dauer: 1225 days 09:45:00
#
# --- Solarproduktion ---
#                            Durchschnitt  Minimum  Maximum
# Solarproduktion Tracker 1    113.128389      0.0   1125.0
# Solarproduktion Tracker 2    214.986268      0.0   1721.0
# Solarproduktion Tracker 3      0.000000      0.0      0.0
# Solarproduktion              328.114657      0.0   2361.0
# --- Wallbox-Leistungen ---
#                                    Durchschnitt  Minimum  Maximum
# Wallbox (ID 0) Gesamtladeleistung     34.312384      0.0   2775.0
# Wallbox Gesamtladeleistung            34.312384      0.0   2775.0
# Wallbox (ID 0) Solarladeleistung      22.446645      0.0   2758.0
# --- Gesamtvergleich ---
# Gesamte Solarproduktion: 37370947.00 kWh
# Gesamter Hausverbrauch ohne Wallbox: 11386698.00 kWh
# Solarproduktion deckt 328.2% des Haushaltsverbrauchs (ohne Wallbox)
# Erste Erkenntnisse:
# - Die höchste Solarproduktion liegt typischerweise zwischen 10 und 15 Uhr.
# - Optimaler Ladezeitpunkt für E-Fahrzeug ist bei hoher Solarproduktion und geringer Netzbezugslast.
# - Nächster Schritt: Prädiktives Modell (z.B. Regression oder Zeitreihenanalyse) für Ladezeit-Vorhersage.
